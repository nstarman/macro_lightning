# %%
import numpy as np

Mhold=[]
Shold=[]
vbar=0.0
f=0.0
# print(f)
Vhold=800.0
for i in range(0,22):
    vx=550.0-i*50.0
    for j in range(0,22):
        vz=550.0-j*50.0
        for k in range(0,22):
            vy=550.0-k*50.0  #this is in the Galactic rest frame
            
            if (np.sqrt(vx**2+vy**2+vz**2)>550.0):
                a=1
                #do nothing
            else:
                vrel=np.sqrt(42.1**2+vx**2+vz**2+(vy-200.0)**2)
                vbar=vbar+(vrel)*np.exp(-(vx**2+vy**2+vz**2)/(250.0**2))*(50.0**3)/(np.pi*250.0**2)**1.5
                Mx=3*vbar*1000
#                 print(vrel)
                if Vhold<vrel:
                    vrel=Vhold
                else:
                    vrel=np.sqrt(42.1**2+vx**2+vz**2+(vy-200.0)**2)
#                 if(vrel>725.0):
#                 f=f+np.exp(-(vx**2+vy**2+vz**2)/(250.0**2))*(50.0**3)/(np.pi*250.0**2)**1.5
#                 print(f)
                sigmax=10**4/(vrel*10**3)**2
                if sigmax<6.0*10**-8:
                    sigmax=6.0*10**-8
                Mhold.append(Mx)
                Shold.append(sigmax)
                Vhold=vrel
# print(np.amin(Shold),np.amax(Shold),len(Mhold))
# print(np.amin(Mhold))

S=[]
M=[]
# Stemp=[]
for k in range(1,10):
    for i in range(1,10):
        Stemp=[]
        for h in range(len(Mhold)):
            if i*10**k < Mhold[h] < (i+1)*10**k:
#                 print(Mhold[h],Shold[h])
#                 print((i+1)*10**k)
#                 print(Shold[h])
                Stemp.append(Shold[h])
        if len(Stemp) > 0:
            S.append(min(Stemp))
            M.append((2*i+1)*10**k/2)
        
print(M,S,len(M),len(S))
# Out:
# [15.0, 35.0, 65.0, 85.0, 150.0, 250.0, 350.0, 450.0, 550.0, 650.0, 750.0, 850.0, 950.0, 1500.0, 2500.0, 3500.0, 4500.0, 5500.0, 6500.0, 7500.0, 8500.0, 9500.0, 15000.0, 25000.0, 35000.0, 45000.0, 55000.0, 65000.0, 75000.0, 85000.0, 95000.0, 150000.0, 250000.0, 350000.0, 450000.0, 550000.0, 650000.0, 750000.0, 850000.0, 950000.0] [6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.000000000000001e-08, 6.18152378393819e-08, 8.046838393171901e-08, 8.046838393171901e-08, 9.825845727737015e-08, 1.0896521078611754e-07, 1.0896521078611754e-07
# ...

# %%
lightning = [[0.0]*2 for i in range(len(M))]
for i in range(0,len(M)):
    lightning[i][0]=M[i]
    lightning[i][1]=S[i]
# lightning.append([950000.0,95])
# lightning.append([0.1,10**-5])
# lightning.append([0.1,6*10**-8])
# lightning.append([45000.1, 6*10**-8])
print(lightning)
# Out:
# [[15.0, 6.000000000000001e-08], [35.0, 6.000000000000001e-08], [65.0, 6.000000000000001e-08], [85.0, 6.000000000000001e-08], [150.0, 6.000000000000001e-08], [250.0, 6.000000000000001e-08], [350.0, 6.000000000000001e-08], [450.0, 6.000000000000001e-08], [550.0, 6.000000000000001e-08], [650.0, 6.000000000000001e-08], [750.0, 6.000000000000001e-08], [850.0, 6.000000000000001e-08], [950.0, 6.000000000000001e-08], [1500.0, 6.000000000000001e-08], [2500.0, 6.000000000000001e-08], [3500.0, 6.000000000000001e-08], [4500.0, 6.000000000000001e-08], [5500.0, 6.000000000000001e-08], [6500.0, 6.000000000000001e-08], [7500.0, 6.000000000000001e-08], [8500.0, 6.000000000000001e-08], [9500.0, 6.000000000000001e-08], [15000.0, 6.000000000000001e-08], [25000.0, 6.18152378393819e-08], [35000.0, 8.046838393171901e-08], [45000.0, 8.046838393171901e-08], [55000.0, 9.825845727737015e-08], [65000.0, 1.0896521078611754e-07], [75000.0, 1.0896521078611754e-07], [85000.0, 1.0896521078611754e-07], [95000.0, 1.49
# ...

# %%
lightning = [[25000.0, 6.18152378393819e-08], 
             [35000.0, 8.046838393171901e-08], [55000.0, 9.825845727737015e-08], 
             [75000.0, 1.0896521078611754e-07],  
             [95000.0, 1.4976245428313878e-07], [150000.0, 1.555877553058925e-07], [250000.0, 2.3939246023870776e-07], 
             [350000.0, 7.006525176897245e-07], [450000.0, 2.3405993338654298e-06],  
             [950000.0, 5.6420354206983716e-06]]

x1=[]
y1=[]
for i in range(len(lightning)):
    x1.append(lightning[i][0])
    y1.append(lightning[i][1])

z = np.polyfit(x1,y1,8)
p = np.poly1d(z)
# print(p)
# print(z)
sigmalightning=[]
for j in range(len(lightning)):
#     test = (z[2] + z[1]*x1[j] + z[0]*x1[j]**2)
#     test = (z[4] + z[3]*x1[j] + z[2]*x1[j]**2 + z[1]*x1[j]**3 + z[0]*x1[j]**4)
    test = (z[8]+z[7]*x1[j]+z[6]*x1[j]**2+z[5]*x1[j]**3+z[4]*x1[j]**4+z[3]*x1[j]**5+z[2]*x1[j]**6+z[1]*x1[j]**7+z[0]*x1[j]**8)
    sigmalightning.append(test)
    delta = ((test-y1[j])/y1[j])*100
#     print(x1[j],y1[j],test,delta)
# print(sigmalightning)
masslightning=[]
upperlightning=[]
for r in range(len(x1)):
    masslightning.append(x1[r])
    upperlightning.append(x1[r]*10**-4)
masslightning.insert(0,6*10**-4)
sigmalightning.insert(0, 6*10**-8)
upperlightning.insert(0, 6*10**-8)
print(masslightning, upperlightning, sigmalightning)
# Out:
# [0.0006000000000000001, 25000.0, 35000.0, 55000.0, 75000.0, 95000.0, 150000.0, 250000.0, 350000.0, 450000.0, 950000.0] [6.000000000000001e-08, 2.5, 3.5, 5.5, 7.5, 9.5, 15.0, 25.0, 35.0, 45.0, 95.0] [6.000000000000001e-08, 6.069172275934775e-08, 8.345457410392224e-08, 9.368722637495567e-08, 1.134393905390877e-07, 1.4785037253300587e-07, 1.5574453066562002e-07, 2.3938062640322454e-07, 7.006541855948315e-07, 2.340599181343086e-06, 5.642035420305724e-06]

# %%
masslightning = [0.0006000000000000001, 25000.0, 35000.0, 55000.0, 75000.0, 95000.0, 150000.0, 250000.0, 350000.0, 450000.0, 950000.0]
upperlightning = [6.000000000000001e-08, 2.5, 3.5, 5.5, 7.5, 9.5, 15.0, 25.0, 35.0, 45.0, 95.0]
sigmalightning = [6.000000000000001e-08, 6.069172275934775e-08, 8.345457410392224e-08, 9.368722637495567e-08, 
                  1.134393905390877e-07, 1.4785037253300587e-07, 1.5574453066562002e-07, 3.3938062640322454e-07, 
                  7.006541855948315e-07, 0.9340599181343086e-06, 5.642035420305724e-06]

# %%
jupitermasslightning = []
uppersigmalightningjupiter = []
for i in range(0,len(masslightning)):
    jupitermasslightning.append(masslightning[i] * 2000.0)
    
for j in range(0, len(jupitermasslightning)):
    uppersigmalightningjupiter.append(jupitermasslightning[j]*10**-4)
    
print(jupitermasslightning,uppersigmalightningjupiter)
# Out:
# [1.2000000000000002, 50000000.0, 70000000.0, 110000000.0, 150000000.0, 190000000.0, 300000000.0, 500000000.0, 700000000.0, 900000000.0, 1900000000.0] [0.00012000000000000003, 5000.0, 7000.0, 11000.0, 15000.0, 19000.0, 30000.0, 50000.0, 70000.0, 90000.0, 190000.0]

# %%
import numpy as np

Mhold=[]
Shold=[]
vbar=0.0
f=0.0
# print(f)
Vhold=800.0
for i in range(0,22):
    vx=550.0-i*50.0
    for j in range(0,22):
        vz=550.0-j*50.0
        for k in range(0,22):
            vy=550.0-k*50.0  #this is in the Galactic rest frame
            
            if (np.sqrt(vx**2+vy**2+vz**2)>550.0):
                a=1
                #do nothing
            elif(np.sqrt(42.1**2+vx**2+vz**2+(vy-200.0)**2)>250.0):
                vrel=np.sqrt(42.1**2+vx**2+vz**2+(vy-200.0)**2)
                vbar=vbar+(vrel)*np.exp(-(vx**2+vy**2+vz**2)/(250.0**2))*(50.0**3)/(np.pi*250.0**2)**1.5
                Mx=10**5*vbar*1000/3
#                 print(vrel)
                if Vhold<vrel:
                    vrel=Vhold
                else:
                    vrel=np.sqrt(42.1**2+vx**2+vz**2+(vy-200.0)**2)
#                 if(vrel>725.0):
                f=f+np.exp(-(vx**2+vy**2+vz**2)/(250.0**2))*(50.0**3)/(np.pi*250.0**2)**1.5
#                 print(f)
                sigmax=(10**-10*(250/vrel)**7)**(1/3)
#                 if sigmax<3.0*10**-12:
#                     sigmax=3.0*10**-12
                Mhold.append(Mx)
                Shold.append(sigmax)
                Vhold=vrel
# print(np.amin(Shold),np.amax(Shold),len(Mhold))
# print(np.amin(Mhold))
# print('final fraction is',f)
S=[]
M=[]
# Stemp=[]
for k in range(5,15):
    for i in range(1,9):
        Stemp=[]
        for h in range(len(Mhold)):
            if i*10**k < Mhold[h] < (i+1)*10**k:
#                 print(Mhold[h],Shold[h])
#                 print((i+1)*10**k)
#                 print(Shold[h])
                Stemp.append(Shold[h])
        if len(Stemp) > 0:
            S.append(min(Stemp))
            M.append((2*i+1)*10**k/2)
        
print(M,S,len(M),len(S))
# Out:
# [250000.0, 450000.0, 650000.0, 1500000.0, 2500000.0, 3500000.0, 4500000.0, 5500000.0, 6500000.0, 7500000.0, 8500000.0, 15000000.0, 25000000.0, 35000000.0, 45000000.0, 55000000.0, 65000000.0, 75000000.0, 85000000.0, 150000000.0, 250000000.0, 350000000.0, 450000000.0, 550000000.0, 650000000.0, 750000000.0, 850000000.0, 1500000000.0, 2500000000.0, 3500000000.0, 4500000000.0, 5500000000.0, 6500000000.0, 7500000000.0, 8500000000.0] [6.34075194929149e-05, 7.394359598768113e-05, 7.394359598768113e-05, 7.394359598768113e-05, 8.179311703783699e-05, 8.179311703783699e-05, 8.728685321870443e-05, 8.728685321870443e-05, 8.728685321870443e-05, 9.029788420702504e-05, 9.029788420702504e-05, 9.134480654274412e-05, 9.134480654274412e-05, 9.462513966290771e-05, 0.00011025527840120905, 0.0001149349203001051, 0.00011657766581917825, 0.00011657766581917825, 0.00011657766581917825, 0.00011826455683100813, 0.00015303995250238566, 0.00020339072728592207, 0.0002081722547506955, 0.0002081722547506955, 0.000287
# ...

# %%
jovian = [[0.0]*2 for i in range(len(M))]
for i in range(0,len(M)):
    jovian[i][0]=M[i]
    jovian[i][1]=S[i]
    
jovian.append([8.5*10**9.0,8.5*10**9*10**-4])
jovian.append([0.634,6.34075194929149e-05])
jovian.append([250000.0, 6.34075194929149e-05])
# jovian.append([15000000.1, 7.6479236974105e-08])
print(jovian)
# Out:
# [[250000.0, 6.34075194929149e-05], [450000.0, 7.394359598768113e-05], [650000.0, 7.394359598768113e-05], [1500000.0, 7.394359598768113e-05], [2500000.0, 8.179311703783699e-05], [3500000.0, 8.179311703783699e-05], [4500000.0, 8.728685321870443e-05], [5500000.0, 8.728685321870443e-05], [6500000.0, 8.728685321870443e-05], [7500000.0, 9.029788420702504e-05], [8500000.0, 9.029788420702504e-05], [15000000.0, 9.134480654274412e-05], [25000000.0, 9.134480654274412e-05], [35000000.0, 9.462513966290771e-05], [45000000.0, 0.00011025527840120905], [55000000.0, 0.0001149349203001051], [65000000.0, 0.00011657766581917825], [75000000.0, 0.00011657766581917825], [85000000.0, 0.00011657766581917825], [150000000.0, 0.00011826455683100813], [250000000.0, 0.00015303995250238566], [350000000.0, 0.00020339072728592207], [450000000.0, 0.0002081722547506955], [550000000.0, 0.0002081722547506955], [650000000.0, 0.00028735007115465196], [750000000.0, 0.00029650306977595226], [850000000.0, 0.000296503069775952
# ...

# %%
# combined macro plot with all constraints upto bolides paper

from scipy.interpolate import interp1d
import io
import csv
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scipy
import os

from pylab import *

pi=np.pi
#matplotlib.pyplot.clf() #clear the plot
# file = open("mica_constraint.txt", 'r')
# data = file.read()
# cob = data.split()
# cob[0] = np.float(1.9952623149688828e-10)
# print(len(cob))
micalines = np.loadtxt("mica_constraint.txt",delimiter = ",",skiprows=1)


superbursts=[[9953843758.093615, 0.947/5], 
             [9918604223.664665, 0.15150427534673], 
             [9899143285.43877, 0.08177823442289134], [9878520053.649336, 0.04793689962142629], 
             [9856817189.094007, 0.02992677043886024], [9834102398.935638, 0.019634954084936207], 
             [9224535550.882074, 0.0015150427534673], [8844959878.530846, 0.00047936899621426287], 
             [7988552717.641915, 0.000378760688366825], [7521505009.8078785, 0.00020444558605722828], 
             [7032966050.946691, 0.00011984224905356572], [6526105884.036355, 7.481692609715061e-05], 
             [6003120011.626727, 4.9087385212340514e-05], [141832274.899224, 3.067961575771282e-06], 
             [30000000, 3e-06],
             [2*10**9,2*10**-3],
             [1*10**10,0.94700001/5]]

superburst1=[[996642914258.7194, 44.1], 
             [993893180855.6251, 2.42406840554768], [990768751618.7228, 0.7669903939428206], 
             [987363263483.1053, 0.3141592653589793], [983720844732.9329, 0.15150427534673], 
             [979828657087.7543, 0.08177823442289134], [975704010729.8671, 0.04793689962142629], 
      [4.8*10**22,140],[7*10**21,7*10**-3],
      [8*10**20,8*10**-8], [8.01*10**10,8*10**-8]]


def CMB(M):
    f = 4.5*10**-7 * M
    return f

#Nuclear Density
def nuc(M):
    f = pi*(3/(4*pi*3.6*10**14))**(2./3) *pow(M,2./3)
    return f

#Black Holes
def BH(M):
    f = pi*(3*10**5)**2 *(M/(2.*10**33))**2
    return f

#Atomic Density
def atom(M):
    f = pi*(3/(4*pi*1*10**0))**(2./3) *pow(M,2./3)
    return f

def BH(M):
    f = pi*(3*10**5)**2 *(M/(2.*10**33))**2
    return f


def KeplerTop(M):
    f = 10.**(-6)*M
    return f

def LMCTop(M):
    f = 10.**(-4)*M
    return f

M1=np.logspace(1,25)
MMica = np.logspace(-10, 2.204)# for M_max=160g
MMica1 = np.logspace(-12,1.43,num=1000)#  2.204 for M_max=160g  1.74 for M_max = 55g  1.43 for M_max=27.5g
MMica2 = np.logspace(1.43,1.74,num=1000)
Mmicro = np.logspace(23.0,28.0)

#Define Plot
fig = plt.figure()
ax = fig.add_subplot(111)

#X-axis
ax.set_xlabel('$M_\t{X}$ [g]',fontsize=18)
ax.set_xlim([M1.min(),M1.max()])

#Y-axis
ymin=10**-15#nuc(M1).min()#10**(-15)
ymax=float(10**25)#nuc(M1).max()#10**15
ax.set_ylim([ymin,ymax])
ax.set_ylabel('$\sigma_\t{X}$ [cm$^{2}$]',fontsize=18)

#Make Plot
ax.loglog(M1, atom(M1), 'k', markersize=4, color='k',lw=1,label='Atomic density',zorder=0)
ax.loglog(M1, nuc(M1), 'k', markersize=4, color='g',lw=2,label='Nuclear density',zorder=0)
ax.loglog(M1, BH(M1), 'k', markersize=4, color='m',lw=3,label='Black holes',zorder=3)

#commenting out lines below here will remove some exclusion regions
#each pair of lines is one constraint

line3 = plt.Polygon(micalines, closed=None, fill=True, facecolor='yellow', edgecolor='black',alpha=0.8, hatch="|",lw=1,zorder=0)# edgecolor='r'
plt.gca().add_line(line3) #e.g. only need to comment out this line (plt.gca()...)to remove mica constraints,
#but you can comment out both the above lines if you want

lineWD = plt.Polygon(WD, closed=None, fill=True, facecolor='blue', edgecolor='black',alpha=0.6, hatch="",lw=1,zorder=2)# edgecolor='r'
plt.gca().add_line(lineWD)

plt.fill_between(M1, CMB(M1),ymax,where=None, color='grey',edgecolor='black',hatch="",alpha=.7,zorder=1)#SIDM ,alpha=.5

linen = plt.Polygon(superbursts, closed=None, fill=True, facecolor='purple', edgecolor='black',alpha=0.6, hatch="",lw=1,zorder=5)# edgecolor='r'
plt.gca().add_line(linen)

# linelightning = plt.Polygon(lightning, closed=None, fill=True, facecolor='cyan', edgecolor='black',alpha=1, hatch="",lw=1,zorder=4)# edgecolor='r'
# plt.gca().add_line(linelightning)

# linejovian = plt.Polygon(jovian, closed=None, fill=True, facecolor='none', edgecolor='black',alpha=1, hatch="+",lw=1,zorder=3)# edgecolor='r'
# plt.gca().add_line(linejovian)

linen1 = plt.Polygon(superburst1, closed=None, fill=True, facecolor='purple', edgecolor='black',alpha=0.6, hatch="//",lw=1,zorder=5)# edgecolor='r'
plt.gca().add_line(linen1)

plt.fill_between(masslightning,sigmalightning ,upperlightning,where=None, facecolor='none',edgecolor='black',hatch="//",alpha=1.0,zorder=8)

plt.fill_between(jupitermasslightning,sigmalightning ,uppersigmalightningjupiter,where=None, facecolor='none',edgecolor='cyan',hatch="//",alpha=1.0,zorder=4)


# plt.fill_between(humanmass,humancross ,humanupper,where=None, facecolor='red',edgecolor='black',hatch="",alpha=1.0,zorder=5)
plt.fill_between(humanmass,humancross ,humanupper,where=None, facecolor='red',edgecolor='black',hatch="",alpha=1.0,zorder=5)
plt.fill_between(DFNmass,DFNcrosssection ,DFNupper,where=None, facecolor='green',edgecolor='black',hatch="",alpha=1.0,zorder=6)

# comment out lines below to remove lensing constraints, each line is a constraint itself
#unlike the above lines
plt.fill_between(Mmicro, BH(Mmicro), LMCTop(Mmicro), where=None,facecolor='brown', edgecolor='black', hatch="/",alpha=1,zorder=2) #BH ,label='BH',


plt.fill_between(M1, ymin, BH(M1), where=None,color='1', edgecolor='', hatch="+",alpha=1,zorder=2) #BH ,label='BH',

#ignore things below this line

# leg = ax.legend(loc='upper left', shadow=True)

# textstr1='WD'
# props = dict(boxstyle='round', facecolor='none', alpha=0.)

# # # place a text box in upper left in axes coords
# ax.text(0.55, 0.33, textstr1, transform=ax.transAxes, fontsize=10,
#     verticalalignment='top', bbox=props,color='white')

# textstr2='CMB'
# props = dict(boxstyle='round', facecolor='none', alpha=0., zorder=4)

# # place a text box in upper left in axes coords
# ax.text(0.4, 0.88, textstr2, transform=ax.transAxes, fontsize=10,
#     verticalalignment='top', bbox=props)

# textstr3='Mica'
# props = dict(boxstyle='round', facecolor='none', alpha=0.)

# # place a text box in upper left in axes coords
# ax.text(0.01, 0.1, textstr3, transform=ax.transAxes, fontsize=10,
#     verticalalignment='top', bbox=props)

# textstr4='NS'
# props = dict(boxstyle='round', facecolor='none', alpha=0.)

# # # place a text box in upper left in axes coords
# ax.text(0.35, 0.34, textstr4, transform=ax.transAxes, fontsize=10,
#     verticalalignment='top', bbox=props)
# textstr5='Humans'
# props = dict(boxstyle='round', facecolor='none', alpha=0.)

# # place a text box in upper left in axes coords
# ax.text(0.00, 0.24, textstr5, transform=ax.transAxes, fontsize=10,
#     verticalalignment='top', bbox=props,color='white')
# textstr6='Bolides'
# props = dict(boxstyle='round', facecolor='none', alpha=0., zorder=5)

# # #place a text box in upper left in axes coords
# ax.text(0.1, 0.40, textstr6, transform=ax.transAxes, fontsize=10,
#     verticalalignment='top', bbox=props)
# textstr7='Lensing'
# props = dict(boxstyle='round', facecolor='none', alpha=0.)

# # place a text box in upper left in axes coords
# ax.text(0.87, 0.6, textstr7, transform=ax.transAxes, fontsize=10,
#     verticalalignment='top', bbox=props)

# textstr92='Grav'
# props = dict(boxstyle='round', facecolor='none', alpha=0.,zorder=6)

# # place a text box in upper left in axes coords
# ax.text(0.76, 0.17, textstr92, transform=ax.transAxes, fontsize=10,
#     verticalalignment='top', bbox=props, rotation =0)

leghumans = Rectangle((0, 0), 1, 1, fc='purple',edgecolor='black', hatch="",alpha=0.6)
legbol = Rectangle((0, 0), 1, 1, fc="purple",edgecolor='black', hatch="/",alpha=0.6)
legbol2 = Rectangle((0, 0), 1, 1, fc='none',edgecolor='green', hatch="+",alpha=0.6)
legfluo = Rectangle((0, 0), 1, 1, fc="none",edgecolor='blue', hatch="//",alpha=1)
leggranite= Rectangle((0, 0), 1, 1, fc="none",edgecolor='purple', alpha=1,hatch="\ ")

leg = ax.legend(loc='upper left', shadow=True)
ax.grid(True)
plt.tight_layout()
plt.savefig('lightningconstraints.pdf')

plt.show()
